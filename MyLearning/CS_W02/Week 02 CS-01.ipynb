# %%
import numpy as np
from seaborn.external.husl import dot_product
from sklearn.metrics import euclidean_distances

v1= np.array([5,3,2])
v2= np.array([3,5,7])
dot_product = np.dot(v1,v2)
print(dot_product)
# Out:
# 44

# %%
v1 = np.array([5,3,2])
v2= np.array([3,5,7])
dist = v1-v2

euclidean_distances =np.linalg.norm(dist)
print(euclidean_distances)
magnitude =np.linalg.norm(v1)
print(magnitude)
# Out:
# 5.744562646538029
# 6.164414002968976

# %%
mt1= np.array([[1,2],
              [3,4]])

mt2= np.array([[1,2,3],
              [4,5,6]])

dot_product = np.dot(mt1,mt2)
print(dot_product)
# Out:
# [[ 9 12 15]
#  [19 26 33]]
